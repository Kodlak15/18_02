# %%
import sys
sys.path.append("../tools")

from plot_functions import *
from integrate import *

# %% [markdown]
# # Unit 1: Double Integrals

# %% [markdown]
# ### Introduction and Review

# %% [markdown]
# ##### Integration warmup

# %% [markdown]
# Warmup 1

# %%
intervals = [
    (-np.pi, np.pi),
    (-np.pi, np.pi),
    (0, 10),
    (0, 10),
]

functions = [
    lambda x: np.sin(x),
    lambda x: np.cos(x),
    lambda x: 5 - x,
    lambda x: np.exp(-x),
]

plot_functions(functions, intervals)

# %% [markdown]
# Warmup 2

# %%
g = lambda x: np.exp(x) * np.cos(x)

x = np.linspace(1, 3, int(1e4))
y = g(x)

plt.plot(x, y);

# %% [markdown]
# ### Double Integrals

# %% [markdown]
# ##### Example 1

# %%
interval = (0, 2)
function = lambda x: x + 1/2
n = int(1e6)

integrate(function, interval, n)
# Out:
# 3.0
